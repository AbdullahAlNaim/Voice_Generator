# %%
pip install gTTS pyttsx3 playsound soundfile transformers datasets sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 5.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.4 MB 13.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 492 kB 51.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 39.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.0 MB 26.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 400 kB 28.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 268 kB 8.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 24.8 MB 23.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133 kB 35.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 115 kB 35.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 228 kB 41.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 41 kB 44 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 737 kB 32.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 390 kB 7.8 MB/s eta 0:00:01
# ...

# %%
import gtts 
from playsound import playsound

# %%
tests = gtts.gTTS("Alright Abdullah lets pop off today. We're going to do 25 minutes of pomodor technique for work. After lets do some planing and thinking about our new defaulting system that we want to implement. I think after we should try to hop back onto with the pomo technique and tackle at least one more ask from the jira tickets. Then we can go wild on web dev projects and maybe read and learn about the fetch api. Or we can go and learn from the online course to relearn express js and crud methods. You can do this Abdullah!")

# %%
tests.save('hello.mp3')

# %%
playsound('hello.mp3')
